# %% [markdown]
# # [Linear Algebra 2021 fall] Homework 3: Cosine Transform and its Applications

# %% [markdown]
# ##### Connect to your google drive, so that you can save file in drive. If you don't connect to google drive, when you reopen the colab file, your modifications would disappear, such as your python code.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##### Go into `drive/MyDrive`, which is the home of your google drive.

# %%
# %cd ./drive/MyDrive
# !pwd
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive

# %% [markdown]
# ##### Download the homework file to colab by `git clone`
# You will download HW3 code in the Github repository. After downloading, press "Refresh" bottom in "File", you will see the `Linear_Algebra_2021fall_Hw3` directory.

# %%
import os
import numpy as np
if not os.path.isdir('Linear_Algebra_2021fall_Hw3'):
  # !git clone https://github.com/DanielLin94144/Linear_Algebra_2021fall_Hw3.git

os.chdir('./Linear_Algebra_2021fall_Hw3')
# Out:
# Cloning into 'Linear_Algebra_2021fall_Hw3'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 40 (delta 13), reused 31 (delta 4), pack-reused 0
# Unpacking objects: 100% (40/40), done.

# %% [markdown]
# Now you are in the `Linear_Algebra_2021fall_Hw3` directory.
# **ALL below codes should be run in this directory**

# %%
# !pwd
# Out:
# /content/drive/My Drive/Linear_Algebra_2021fall_Hw3

# %% [markdown]
# # What you should do?
# After downloading the files, we have two problems in **p1.py** and **p2.py** respectively.

# %% [markdown]
# # [Problem 1] 1D consine transform
# TODO:
# You should finish below functions and missing code in `p1.py`
#
# 1. *CosineTrans*
# 2. *InvCosineTrans*
# 3. *gen_basis*
# 4. missing code in `__main__`: find f1 and f3

# %% [markdown]
# The testing data is in `example_data/test.txt`. Feel free to use testing data to check your code.
# ##### Below code is just loading the test waveform and plot it for visaulization.

# %%
from p1 import plot_wave
x = np.loadtxt('example_data/test.txt', dtype = np.float32).reshape(-1, 1)
plot_wave(x, 'test_wave.png')

# %% [markdown]
# After finishing all the `#TODO` in **p1.py**,  run the following command to get the output (`f1.png`, `f3.png`, `freq.png`).

# %%
# !python p1.py example_data/test.txt ./
# Out:
# Traceback (most recent call last):
#   File "p1.py", line 51, in <module>
#     plot_ak(a, path=os.path.join(out_directory_path, 'freq.png'))
# NameError: name 'a' is not defined

# %% [markdown]
# # [Problem 2] 2D cosine transform and JPEG compression
# Please finish two function in `p2.py`:
# 1.  *CosineTrans2d*
# 2.  *InvCosineTrans2d*
# **Since the function in `p2.py` also use `gen_basis` function in `p1.py`, you should make sure `gen_basis` function is correct and then continuing to Problem 2.**
#
# After implementing these two functions, you can run below python code to get the JPEG compression image, named `reconstructed.png`.
#
# (Please not modify other code in `p2.py`, or your reconstructed image might gets wrong.)

# %%
# !python p2.py example_data/test.png ./
# Out:
# JPEG compression: only use 0.15071487426757812 size of original image

# %% [markdown]
# ### Visualize the JPEG compression result by following code

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

ori_I = cv2.imread('example_data/test.png')
JPEG_reconstructed_I = cv2.imread('reconstructed.png')
example_reconstructed_I = cv2.imread('./example_output/reconstructed.png')
print('Original image')
cv2_imshow(ori_I)
print('JEPG compressed image')
cv2_imshow(JPEG_reconstructed_I)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FCA9451A790>
# JEPG compressed image
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FCA9445D450>
